# %%
import cbsodata
import pandas
import seaborn as sns

# %%
tables = cbsodata.get_table_list()
print(tables[0])
# Out:
# {'Updated': '2021-11-01T02:00:00', 'ID': 0, 'Identifier': '84669NED', 'Title': "Banen van werknemers; internationaliseringskenmerken van bedrijven, '10-'18", 'ShortTitle': 'Banen; internationalisering bedrijven', 'ShortDescription': '\nDeze tabel bevat informatie over werknemersbanen in Nederland. Het aantal banen wordt uitgesplitst naar diverse achtergrondkenmerken van de werknemers en de bedrijven waarvoor zij in dienst zijn. Bij de bedrijven wordt met name onderscheid gemaakt tussen bedrijven onder Nederlandse zeggenschap en bedrijven onder buitenlandse zeggenschap, en de internationale handel van het bedrijf. Werknemerskenmerken zijn onder meer opleidingsniveau en nationaliteit. Daarbij wordt de top vijf van meest voorkomende nationaliteiten bij bedrijven onder buitenlandse zeggenschap gerapporteerd. Het opleidingsniveau wordt gegeven bij alle selecties (uitgezonderd buitenlandse nationaliteiten) met tenminste duizend directe observaties.\n\nGegevens beschikbaar van 2010 tot en met 2018.\n\nStatus van de cijfers:\nDe cijfers in deze tabel zijn voorlopig.\n\nWijzigingen per 1 november 2021:\nGeen, deze tabel is stopgezet.\n\nWanneer komen er nieuwe cijfers?\nNiet meer van toepassing.\n', 'Summary': 'werknemersbanen, voltijdequivalenten, arbeidsvolume, loon\nInternationale handel in goederen & diensten, multinationals, zeggenschap', 'Modified': '2020-12-14T02:00:00', 'MetaDataModified': '2021-11-01T02:00:00', 'ReasonDelivery': 'Stopgezet', 'ExplanatoryText': '', 'OutputStatus': 'Gediscontinueerd', 'Source': 'CBS.', 'Language': 'nl', 'Catalog': 'CBS', 'Frequency': 'Stopgezet', 'Period': '2010 t/m 2018', 'SummaryAndLinks': 'werknemersbanen, voltijdequivalenten, arbeidsvolume, loon<br />Internationale handel in goederen & diensten, multinationals, zeggenschap<br /><a href="http://opendata.cbs.nl/ODataApi/OData/84669NED">http://opendata.cbs.nl/ODataApi/OData/84669NED</a><br /><a href="http://opendata.cbs.nl/ODataFeed/OData/84669NED">http://opendata.cbs.nl/ODataFeed/OData/84669NED</a>', 'ApiUrl': 'https://opendata.cbs.nl/ODataApi/OData/84669NED', 'FeedUrl': 'https://opendata.cbs.nl/ODataFeed/OData/84669NED', 'DefaultPresentation': 'ts=1606984891185&graphtype=Table&r=InternationaliseringskenmerkenBedrijf&k=Topics&t=BedrijfstakkenBranchesSBI2008,Bedrijfsgrootte,KenmerkenBaanEnWerknemer,Perioden', 'DefaultSelection': "$filter=((BedrijfstakkenBranchesSBI2008 eq 'T001081')) and ((Bedrijfsgrootte eq 'T001098')) and ((KenmerkenBaanEnWerknemer eq 'T001025')) and ((Perioden eq '2018JJ00'))&$select=BedrijfstakkenBranchesSBI2008, Bedrijfsgrootte, InternationaliseringskenmerkenBedrijf, KenmerkenBaanEnWerknemer, Perioden, Banen_1, Arbeidsvolume_2, Uurloon_3, PerBaanPerWeekExclusiefOverwerk_5", 'GraphTypes': 'Table,Bar,Line', 'RecordCount': 304128, 'ColumnCount': 10, 'SearchPriority': '1'}

# %%
print(tables[0])
# Out:
# {'Updated': '2021-11-01T02:00:00', 'ID': 0, 'Identifier': '84669NED', 'Title': "Banen van werknemers; internationaliseringskenmerken van bedrijven, '10-'18", 'ShortTitle': 'Banen; internationalisering bedrijven', 'ShortDescription': '\nDeze tabel bevat informatie over werknemersbanen in Nederland. Het aantal banen wordt uitgesplitst naar diverse achtergrondkenmerken van de werknemers en de bedrijven waarvoor zij in dienst zijn. Bij de bedrijven wordt met name onderscheid gemaakt tussen bedrijven onder Nederlandse zeggenschap en bedrijven onder buitenlandse zeggenschap, en de internationale handel van het bedrijf. Werknemerskenmerken zijn onder meer opleidingsniveau en nationaliteit. Daarbij wordt de top vijf van meest voorkomende nationaliteiten bij bedrijven onder buitenlandse zeggenschap gerapporteerd. Het opleidingsniveau wordt gegeven bij alle selecties (uitgezonderd buitenlandse nationaliteiten) met tenminste duizend directe observaties.\n\nGegevens beschikbaar van 2010 tot en met 2018.\n\nStatus van de cijfers:\nDe cijfers in deze tabel zijn voorlopig.\n\nWijzigingen per 1 november 2021:\nGeen, deze tabel is stopgezet.\n\nWanneer komen er nieuwe cijfers?\nNiet meer van toepassing.\n', 'Summary': 'werknemersbanen, voltijdequivalenten, arbeidsvolume, loon\nInternationale handel in goederen & diensten, multinationals, zeggenschap', 'Modified': '2020-12-14T02:00:00', 'MetaDataModified': '2021-11-01T02:00:00', 'ReasonDelivery': 'Stopgezet', 'ExplanatoryText': '', 'OutputStatus': 'Gediscontinueerd', 'Source': 'CBS.', 'Language': 'nl', 'Catalog': 'CBS', 'Frequency': 'Stopgezet', 'Period': '2010 t/m 2018', 'SummaryAndLinks': 'werknemersbanen, voltijdequivalenten, arbeidsvolume, loon<br />Internationale handel in goederen & diensten, multinationals, zeggenschap<br /><a href="http://opendata.cbs.nl/ODataApi/OData/84669NED">http://opendata.cbs.nl/ODataApi/OData/84669NED</a><br /><a href="http://opendata.cbs.nl/ODataFeed/OData/84669NED">http://opendata.cbs.nl/ODataFeed/OData/84669NED</a>', 'ApiUrl': 'https://opendata.cbs.nl/ODataApi/OData/84669NED', 'FeedUrl': 'https://opendata.cbs.nl/ODataFeed/OData/84669NED', 'DefaultPresentation': 'ts=1606984891185&graphtype=Table&r=InternationaliseringskenmerkenBedrijf&k=Topics&t=BedrijfstakkenBranchesSBI2008,Bedrijfsgrootte,KenmerkenBaanEnWerknemer,Perioden', 'DefaultSelection': "$filter=((BedrijfstakkenBranchesSBI2008 eq 'T001081')) and ((Bedrijfsgrootte eq 'T001098')) and ((KenmerkenBaanEnWerknemer eq 'T001025')) and ((Perioden eq '2018JJ00'))&$select=BedrijfstakkenBranchesSBI2008, Bedrijfsgrootte, InternationaliseringskenmerkenBedrijf, KenmerkenBaanEnWerknemer, Perioden, Banen_1, Arbeidsvolume_2, Uurloon_3, PerBaanPerWeekExclusiefOverwerk_5", 'GraphTypes': 'Table,Bar,Line', 'RecordCount': 304128, 'ColumnCount': 10, 'SearchPriority': '1'}

# %%
info = cbsodata.get_info('84669NED')
info['Title']
info['Modified']
# Out:
# '2020-12-14T02:00:00'

# %%
tables = pandas.DataFrame(cbsodata.get_table_list())
tables.head()
# Out:
#                Updated  ID Identifier  \
# 0  2021-11-01T02:00:00   0   84669NED
# 1  2023-10-06T02:00:00   1   83583NED
# 2  2023-10-06T02:00:00   2   83582NED
# 3  2023-12-21T02:00:00   3   84826NED
# 4  2024-02-09T02:00:00   4   85483NED
#
#                                                Title  \
# 0  Banen van werknemers; internationaliseringsken...
# 1  Banen van werknemers; bedrijfsgrootte en econo...
# 2  Banen van werknemers in december; economische ...
# 3  Ontslagen werknemers door faillissement; gesla...
# 4  Werknemersbanen en reisafstand; geslacht, leef...
#
#                                 ShortTitle  \
# 0    Banen; internationalisering bedrijven
# 1    Banen van werknemers; bedrijfsgrootte
# 2     Banen van werknemers; SBI2008, regio
# 3  Ontslagen werknemers door faillissement
# 4    Woon-werkafstand werknemers; leeftijd
#
#                                     ShortDescription  \
# 0  \nDeze tabel bevat informatie over werknemersb...
# 1  \nDeze tabel geeft informatie over het gemidde...
# 2  \nDeze tabel geeft informatie over het gemidde...
# 3  \nDeze tabel bevat cijfers over het aantal wer...
# 4  \nDeze tabel brengt het aantal banen van werkn...
#
#                                              Summary             Modified  \
# 0  werknemersbanen, voltijdequivalenten, arbeidsv...  2020-12-14T02:00:00
# 1  Banen van werknemers, bedrijfsgrootte, economi...  2023-10-06T02:00:00
# 2  Banen van werknemers, bedrijfsgrootte, economi...  2023-10-06T02:00:00
# 3  ontslagen werknemers\ngeslacht, leeftijd, bedr...  2023-12-21T02:00:00
# 4  Banen van werknemers naar geslacht, leeftijd, ...  2024-02-09T02:00:00
#
#       MetaDataModified ReasonDelivery  ...         Period  \
# 0  2021-11-01T02:00:00      Stopgezet  ...  2010 t/m 2018
# 1  2023-10-06T02:00:00  Actualisering  ...      2010-2022
# 2  2023-10-06T02:00:00     Herontwerp  ...      2010-2022
# 3  2023-12-21T02:00:00  Actualisering  ...      2015-2022
# 4  2024-02-09T02:00:00  Actualisering  ...      2021-2022
#
#                                      SummaryAndLinks  \
# 0  werknemersbanen, voltijdequivalenten, arbeidsv...
# 1  Banen van werknemers, bedrijfsgrootte, economi...
# 2  Banen van werknemers, bedrijfsgrootte, economi...
# 3  ontslagen werknemers<br />geslacht, leeftijd, ...
# 4  Banen van werknemers naar geslacht, leeftijd, ...
#
#                                             ApiUrl  \
# 0  https://opendata.cbs.nl/ODataApi/OData/84669NED
# 1  https://opendata.cbs.nl/ODataApi/OData/83583NED
# 2  https://opendata.cbs.nl/ODataApi/OData/83582NED
# 3  https://opendata.cbs.nl/ODataApi/OData/84826NED
# 4  https://opendata.cbs.nl/ODataApi/OData/85483NED
#
#                                             FeedUrl  \
# 0  https://opendata.cbs.nl/ODataFeed/OData/84669NED
# 1  https://opendata.cbs.nl/ODataFeed/OData/83583NED
# 2  https://opendata.cbs.nl/ODataFeed/OData/83582NED
# 3  https://opendata.cbs.nl/ODataFeed/OData/84826NED
# 4  https://opendata.cbs.nl/ODataFeed/OData/85483NED
#
#                                  DefaultPresentation  \
# 0  ts=1606984891185&graphtype=Table&r=Internation...
# 1  ts=1695202142906&graphtype=Table&r=Bedrijfstak...
# 2  ts=1695206028076&graphtype=Table&r=Bedrijfstak...
# 3  ts=1671008486405&graphtype=Table&r=Bedrijfstak...
# 4  ts=1706769009588&graphtype=Table&r=WoonregioS,...
#
#                                     DefaultSelection      GraphTypes  \
# 0  $filter=((BedrijfstakkenBranchesSBI2008 eq 'T0...  Table,Bar,Line
# 1  $filter=((BedrijfstakkenBranchesSBI2008 eq 'T0...  Table,Bar,Line
# 2  $filter=((BedrijfstakkenBranchesSBI2008 eq 'T0...       Table,Map
# 3  $filter=((Geslacht eq 'T001038')) and ((Leefti...  Table,Bar,Line
# 4  $filter=((Geslacht eq 'T001038') or (Geslacht ...   Table,Bar,Map
#
#   RecordCount ColumnCount SearchPriority
# 0      304128          10              1
# 1        9672           4              2
# 2      205296           4              3
# 3        2976           5              2
# 4      161448           7              2
#
# [5 rows x 26 columns]

# %%
data = pandas.DataFrame(cbsodata.get_data('80416NED'))
data.head()
# Out:
#    ID                  Perioden  BenzineEuro95_1  Diesel_2  Lpg_3
# 0   0     2006 zondag 1 januari            1.325     1.003  0.543
# 1   1    2006 maandag 2 januari            1.328     1.007  0.542
# 2   2    2006 dinsdag 3 januari            1.332     1.007  0.540
# 3   3   2006 woensdag 4 januari            1.348     1.020  0.550
# 4   4  2006 donderdag 5 januari            1.347     1.021  0.550

# %%
# 
def maand_als_nummer(maand):
    maand_naam = ['januari', 'februari', 'maart', 'april', 'mei', 'juni', 'juli', 'augustus', 'september', 'oktober', 'november', 'december']
    
    if maand in maand_naam:
        maand_nummer = maand_naam.index(maand) + 1
        return maand_nummer

# %%
# Create extra colums to add years, months and days
# empty lists
years = []
months = []
days = []

# for every entry append the row and fill in the extra columns
for entry in data.index:
    periods = data['Perioden'][entry].split(' ')
    year = periods[0]
    month = maand_als_nummer(periods[3])
    day = periods[2]
    years.append(year)
    months.append(month)
    days.append(day)

# Create new colums prepopulated with all values
if not 'year' in data:
    data.insert(5, "year", years)
if not 'month' in data:
    data.insert(6, "month", months)
if not 'day' in data:
    data.insert(7, "day", days)

# %%
data
# Out:
#         ID                  Perioden  BenzineEuro95_1  Diesel_2  Lpg_3  year  \
# 0        0     2006 zondag 1 januari            1.325     1.003  0.543  2006
# 1        1    2006 maandag 2 januari            1.328     1.007  0.542  2006
# 2        2    2006 dinsdag 3 januari            1.332     1.007  0.540  2006
# 3        3   2006 woensdag 4 januari            1.348     1.020  0.550  2006
# 4        4  2006 donderdag 5 januari            1.347     1.021  0.550  2006
# ...    ...                       ...              ...       ...    ...   ...
# 7067  7067      2025 donderdag 8 mei            1.858     1.588  0.785  2025
# 7068  7068        2025 vrijdag 9 mei            1.859     1.588  0.783  2025
# 7069  7069      2025 zaterdag 10 mei            1.860     1.584  0.786  2025
# 7070  7070        2025 zondag 11 mei            1.863     1.586  0.788  2025
# 7071  7071       2025 maandag 12 mei            1.864     1.590  0.784  2025
#
#       month day
# 0         1   1
# 1         1   2
# 2         1   3
# 3         1   4
# 4         1   5
# ...     ...  ..
# 7067      5   8
# 7068      5   9
# 7069      5  10
# 7070      5  11
# 7071      5  12
#
# [7072 rows x 8 columns]

# %%
benzine = sns.relplot(data=data, x="year", y="BenzineEuro95_1", kind="line", aspect=0.6*3)
diesel = sns.relplot(data=data, x="year", y="Diesel_2", hue='month', kind="line", aspect=0.6*3)
lpg = sns.relplot(data=data, x="year", y="Lpg_3", hue="month", kind="line", aspect=0.6*3)

benzine.set_ylabels("Benzine prijs in euro").set_xlabels("Jaar")
diesel.set_ylabels("Diesel prijs in euro").set_xlabels("Jaar")
lpg.set_ylabels("Lpg prijs in euro").set_xlabels("Jaar")

# %%
natural_gas_balance = pandas.DataFrame(cbsodata.get_data('84575ENG'))
natural_gas_balance
# Out:
#       ID           Periods  GrossProduction_1  \
# 0      0              1929                NaN
# 1      1              1930                NaN
# 2      2              1931                NaN
# 3      3              1932                NaN
# 4      4              1933                NaN
# ..   ...               ...                ...
# 877  877     2024 December            11573.0
# 878  878  2024 4th quarter            32986.0
# 879  879              2024           123153.0
# 880  880      2025 January            12249.0
# 881  881     2025 February            12050.0
#
#      OwnConsumptionForElectrProduction_2  NetProductionTotal_3  \
# 0                                    NaN                   NaN
# 1                                    NaN                   NaN
# 2                                    NaN                   NaN
# 3                                    NaN                   NaN
# 4                                    NaN                   NaN
# ..                                   ...                   ...
# 877                                338.0               11235.0
# 878                                920.0               32065.0
# 879                               3013.0              120140.0
# 880                                377.0               11871.0
# 881                                330.0               11720.0
#
#      NuclearEnergy_4  FuelsTotal_5  Coal_6  PetroleumProducts_7  NaturalGas_8  \
# 0                NaN           NaN     NaN                  NaN           NaN
# 1                NaN           NaN     NaN                  NaN           NaN
# 2                NaN           NaN     NaN                  NaN           NaN
# 3                NaN           NaN     NaN                  NaN           NaN
# 4                NaN           NaN     NaN                  NaN           NaN
# ..               ...           ...     ...                  ...           ...
# 877            361.0        6486.0  1402.0                 89.0        4030.0
# 878           1064.0       19715.0  4103.0                309.0       12664.0
# 879           3382.0       61764.0  9607.0               1330.0       42935.0
# 880            362.0        8080.0  1681.0                126.0        5302.0
# 881            326.0        7692.0  1756.0                121.0        4926.0
#
#      ...  UnitedKingdom_21  Norway_22  ExportsTotal_23  Belgium_24  \
# 0    ...               NaN        NaN                0         0.0
# 1    ...               NaN        NaN                0         0.0
# 2    ...               NaN        NaN                0         0.0
# 3    ...               NaN        NaN                0         0.0
# 4    ...               NaN        NaN                0         0.0
# ..   ...               ...        ...              ...         ...
# 877  ...              25.0      355.0             2228      1181.0
# 878  ...             255.0     1102.0             6894      3805.0
# 879  ...            1617.0     3487.0            24249      9843.0
# 880  ...               4.0      391.0             2261      1091.0
# 881  ...             172.0      344.0             2832      1071.0
#
#      Denmark_25  Germany_26  UnitedKingdom_27  Norway_28  \
# 0           NaN         0.0               NaN        NaN
# 1           NaN         0.0               NaN        NaN
# 2           NaN         0.0               NaN        NaN
# 3           NaN         0.0               NaN        NaN
# 4           NaN         0.0               NaN        NaN
# ..          ...         ...               ...        ...
# 877       103.0       862.0              63.0       20.0
# 878       335.0      1926.0             780.0       47.0
# 879      1723.0      8791.0            3298.0      594.0
# 880       115.0       970.0              72.0       13.0
# 881       199.0      1303.0             257.0        4.0
#
#      DistributionLosses_29  NetConsumptionCalculated_30
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# ..                     ...                          ...
# 877                  462.0                      10166.0
# 878                 1335.0                      29158.0
# 879                 5028.0                     110891.0
# 880                  469.0                      10719.0
# 881                  420.0                       9636.0
#
# [882 rows x 32 columns]
